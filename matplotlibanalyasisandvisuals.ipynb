# %%
#Ke Feng
# I have not given or received any unauthorized assistance on this assignment.

# %%
#1.2.Import Relevant Libraries 
import numpy as np
from matplotlib import pyplot as plt

# %%
#3.4.Downlaod the file
a=np.loadtxt("housing.csv",delimiter=",",dtype='str')

# %%
# 5.Write code to get the size of housing.
np.size(a)
# Out:
# 206410

# %%
#6.Write code to get the data type of the data in housing.
a.dtype
# Out:
# dtype('<U18')

# %%
#7.Write code to get the dimensions of housing.
a.shape
# Out:
# (20641, 10)

# %%
#8.Create a labeled histogram of population.
population=np.loadtxt("housing.csv",skiprows=1,usecols=(5),delimiter=",",dtype="float")
plt.hist(population, bins=50)
# Out:
# (array([4.199e+03, 8.974e+03, 4.340e+03, 1.584e+03, 7.190e+02, 3.300e+02,
#         1.890e+02, 9.100e+01, 5.600e+01, 4.500e+01, 5.000e+01, 1.300e+01,
#         1.400e+01, 1.300e+01, 5.000e+00, 4.000e+00, 3.000e+00, 3.000e+00,
#         2.000e+00, 0.000e+00, 0.000e+00, 2.000e+00, 2.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([3.000000e+00, 7.165800e+02, 1.430160e+03, 2.143740e+03,
#         2.857320e+03, 3.570900e+03, 4.284480e+03, 4.998060e+03,
#         5.711640e+03, 6.425220e+03, 7.138800e+03, 7.852380e+03,
#         8.565960e+03, 9.279540e+03, 9.993120e+03, 1.070670e+04,
#         1.142028e+04, 1.213386e+04, 1.284744e+04, 1.356102e+04,
# ...

# %%
#9.Create a bar chart for ocean_proximity.
op=np.loadtxt("housing.csv",skiprows=1,usecols=(9),delimiter=",",dtype='str')
index={}
count=0
for i in op:
    if i in index:
        index[i] +=1
    else:
        index[i]=1
keys=list(dict.keys())
counts=list(dict.values())
plt.bar(keys, counts)
# Out:
# <BarContainer object of 5 artists>

# %%
#10.Create a labeled scatter plot of age (x-axis) and pop (y-axis).  Color the points in the scatterplot based on price.
plt.figure(1)
age=np.loadtxt("housing.csv",skiprows=1,usecols=(2),delimiter=",",dtype='float')
pop=np.loadtxt("housing.csv",skiprows=1,usecols=(5),delimiter=",",dtype='float')
price=np.loadtxt("housing.csv",skiprows=1,usecols=(8),delimiter=",",dtype='float')
plt.scatter(age,pop,c=price, s=4)
plt.show()

# %%
#11 Write few lines to analyze
#The x axis the age, and the y axis is the population. As age goes up, house buying population decreases. The price is the colr, and tehy concentrate on range 5000-10000.
